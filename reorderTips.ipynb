# %% [markdown]
# # Assessment 2019 - Fundamentals of Data Analysis
#
# ## Due: November 29th, 2019
#
# ### This contains all of the information for my 2019 assignment submission. Work on this began 3rd October 2019 with a final submission date of November 29th.

# %% [markdown]
# ### 1.
# Create a git repository and make it available online for the lecturer
# to clone. The repository should contain all your work for this assessment. Within the repository, create a jupyter notebook that uses descriptive statistics and plots to describe the tips dataset.
#
#
# ### 2.
# To the above jupyter notebook add a section that discusses and
# analyses whether there is a relationship between the total bill and tip amount.
#
# ### 3.
# Using the same notebook, analyse the relationship between the
# variables within the dataset. You are free to interpret this as you wish — for
# example, you may analyse all pairs of variables, or select a subset and analyse
# those.

# %% [markdown]
# A tip or gratuity is a sum of money in addition to the basic price for a product or service given by the customer to the one providing the product or service.  Tipping is not common place in Ireland but is becoming more popular.  It is synonymous with America where workers who earn a lower base pay (or sometimes no base pay at all) rely on tips for income.  The common perception is that in a restaurant tips will come to between 15% and 20%.  At the end of this I will include a linear regression model to see if the tips dataset stays true to this.
#
#
# The tips data set was obtained in the early to mid 1990's by a food server in a restaurant in the United States over a period of two and a half months from all the customers they served.  The exact date has been difficult to track down with some sources stating it was 1990 and some 1995 so to err on the side of caution I have included both. The restaurant, part of an unnamed national chain, was located in a surburban shopping mall and carried a varied menu.  In accordance with local law, the restaurant seated customers in a non-smoking section if they so wished.  The dataframe contains 7 columns.
#
# #### total_bill : Total bill (cost of the meal), including tax, in US dollars
#
# #### tip : Tip (gratuity) in US dollars
#
# #### sex : Sex of person paying for the meal
#
# #### smoker : Smoker in party No/Yes
#
# #### day : Thur, Fri, Sat, Sun
#
# #### time : The time of the meal, i.e. lunch or dinner
#
# #### size : The number of people in the group (varies between 1 and 6)

# %% [markdown]
# ## Description

# %%
#Import libraries needed
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load and show all the information contained within the tips dataset.  This gives a chance to look at the information in its entirety before I begin to decipher it.
tips = sns.load_dataset("tips")
tips.head(245)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# ...

# %%
import os
import csv

# %% [markdown]
# Print working directory.  This isn’t strictly part of the assessment.  I am just playing around with different methods of importing data to work with.  It is for future projects and to refresh my earlier python programming memory.

# %%
pwd
# Out:
# 'C:\\Users\\Rebecca\\Desktop\\Fund Data 2019\\Fundamentals-of-Data-Analysis-Assessment-2019'

# %%
# Look at the first 5 lines of the csv file   
variable = pd.read_csv('tips.csv', delimiter = ',')
    
variable.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size_of_party
# 0       16.99  1.01  Female     No  Sun  Dinner              2
# 1       10.34  1.66    Male     No  Sun  Dinner              3
# 2       21.01  3.50    Male     No  Sun  Dinner              3
# 3       23.68  3.31    Male     No  Sun  Dinner              2
# 4       24.59  3.61  Female     No  Sun  Dinner              4

# %%
# using the iloc function, again selecting the first 5 lines
variable.iloc [1:5]
# Out:
#    total_bill   tip     sex smoker  day    time  size_of_party
# 1       10.34  1.66    Male     No  Sun  Dinner              3
# 2       21.01  3.50    Male     No  Sun  Dinner              3
# 3       23.68  3.31    Male     No  Sun  Dinner              2
# 4       24.59  3.61  Female     No  Sun  Dinner              4

# %%
# Look at the last 5 lines of the file
variable = pd.read_csv('tips.csv', delimiter = ',')
    
variable.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size_of_party
# 239       29.03  5.92    Male     No   Sat  Dinner              3
# 240       27.18  2.00  Female    Yes   Sat  Dinner              2
# 241       22.67  2.00    Male    Yes   Sat  Dinner              2
# 242       17.82  1.75    Male     No   Sat  Dinner              2
# 243       18.78  3.00  Female     No  Thur  Dinner              2

# %%
# Call in the csv file
df = pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv")

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# ...

# %%
# An alternative way to call the csv file and look at the heading (first 5 lines)
variable = pd.read_csv(r"C:/Users/Rebecca/Desktop/Fund Data 2019/Fundamentals-of-Data-Analysis-Assessment-2019/tips.csv")
variable.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size_of_party
# 0       16.99  1.01  Female     No  Sun  Dinner              2
# 1       10.34  1.66    Male     No  Sun  Dinner              3
# 2       21.01  3.50    Male     No  Sun  Dinner              3
# 3       23.68  3.31    Male     No  Sun  Dinner              2
# 4       24.59  3.61  Female     No  Sun  Dinner              4

# %%
# Begin to take a deeper look at the information within tips dataset. How many males vs females
tips.groupby(by='sex').size()
# Out:
# sex
# Male      157
# Female     87
# dtype: int64

# %% [markdown]
# From the above infromation, 157 meals were served to male diners and 87 to female diners.  That is almost twice as many males as females.

# %%
# Grouped according to the sex of the diners, looking at the total bill column.  The describe() function gives more statistics than the one used above
tips.groupby(by="sex")["total_bill"].describe()
# Out:
#         count       mean       std   min    25%    50%    75%    max
# sex
# Male    157.0  20.744076  9.246469  7.25  14.00  18.35  24.71  50.81
# Female   87.0  18.056897  8.009209  3.07  12.75  16.40  21.52  44.30

# %% [markdown]
# The count refers to the number of valid values within the table. So, there are no details missing. The mean is the sum of all the values within the column divided by the count. As already written above, the mean for males are 20.75 and females are 18.06. The standard deviation is a measure of how far away from the mean values typically are. A big standard deviation indicated the spread away from the mean the values are. The min value is the minimum amount which was spent while the max means the opposite. The 50% is the median, half the values are above it and half below it. Here we see that males consistently spent more than females for all the percentages listed above.

# %%
# Data Frame Information provides a concise summary.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
# total_bill    244 non-null float64
# tip           244 non-null float64
# sex           244 non-null object
# smoker        244 non-null object
# day           244 non-null object
# time          244 non-null object
# size          244 non-null int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.4+ KB

# %%
# Another way to check the information, see if there is any missing/null values
tips.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %% [markdown]
# This tells us that there is no information missing.

# %%
# What was the average of the total bill for lunch and dinner 
tips.groupby(by='time')['total_bill'].mean()
# Out:
# time
# Lunch     17.168676
# Dinner    20.797159
# Name: total_bill, dtype: float64

# %% [markdown]
# The average cost of a lunch was 17.17 and the average cost of each dinner served was 20.80.

# %%
# What was the average of the total bill broken down into males and females
tips.groupby(by='sex')['total_bill'].mean()
# Out:
# sex
# Male      20.744076
# Female    18.056897
# Name: total_bill, dtype: float64

# %% [markdown]
# The average male diner spent 20.75 while the average female spent 18.06

# %%
# How many meals were served to males and females subdivided by days of the week.  The by argument, used with the groupby, and a list of the columns we want to group by.
tips.groupby(by=['sex', 'day']).size()
# Out:
# sex     day
# Male    Thur    30
#         Fri     10
#         Sat     59
#         Sun     58
# Female  Thur    32
#         Fri      9
#         Sat     28
#         Sun     18
# dtype: int64

# %% [markdown]
# From the above Thursday and Friday meals remained broadly similar when broken down by sex. But for Saturday and Sunday there is a huge discrepancy with many more males than females.

# %%
# The max daily tips
tips.groupby(by='day')['tip'].max()
# Out:
# day
# Thur     6.70
# Fri      4.73
# Sat     10.00
# Sun      6.50
# Name: tip, dtype: float64

# %% [markdown]
# The max daily tips were almost the same Thursday and Sunday with a dip on Friday and a large increase on Saturday.

# %%
# The max daily tips further divided by sex
tips.groupby(by=['sex', 'day']).max()
# Out:
#              size    tip  total_bill
# sex    day
# Male   Thur     6   6.70       41.19
#        Fri      4   4.73       40.17
#        Sat      5  10.00       50.81
#        Sun      6   6.50       48.17
# Female Thur     6   5.17       43.11
#        Fri      3   4.30       22.75
#        Sat      4   6.50       44.30
#        Sun      5   5.20       35.26

# %% [markdown]
# Males gave higher tips compared to their female counterparts for 3 out of the 4 days.

# %%
# The smallest daily tip the server received on each day of the week by each sex.
tips.groupby(by=['sex', 'day']).min()
# Out:
#              size   tip  total_bill
# sex    day
# Male   Thur     2  1.44        7.51
#        Fri      1  1.50        8.58
#        Sat      2  1.00        7.74
#        Sun      2  1.32        7.25
# Female Thur     1  1.25        8.35
#        Fri      2  1.00        5.75
#        Sat      1  1.00        3.07
#        Sun      2  1.01        9.60

# %% [markdown]
# Females gave the smallest tip every day compared to males.

# %%
# Total daily spend by each sex
tips.groupby(by=['sex', 'day'])['total_bill'].sum()
# Out:
# sex     day
# Male    Thur     561.44
#         Fri      198.57
#         Sat     1227.35
#         Sun     1269.46
# Female  Thur     534.89
#         Fri      127.31
#         Sat      551.05
#         Sun      357.70
# Name: total_bill, dtype: float64

# %% [markdown]
# Males spent more each day and significantly more than females at the weekends. Fridays totals are far lower than the rest.

# %%
# Total daily spend by each sex
tips.groupby(by=['day', "time", "sex"])['total_bill'].sum()
# Out:
# day   time    sex
# Thur  Lunch   Male       561.44
#               Female     516.11
#       Dinner  Female      18.78
# Fri   Lunch   Male        34.16
#               Female      55.76
#       Dinner  Male       164.41
#               Female      71.55
# Sat   Dinner  Male      1227.35
#               Female     551.05
# Sun   Dinner  Male      1269.46
#               Female     357.70
# Name: total_bill, dtype: float64

# %% [markdown]
# Males spent more each meal time apart from two instances.  Firstly, there was no dinner time information for males on Thursday.  Secondly, females spent more at lunch time on Friday.

# %%
# Daily tip total by each sex
tips.groupby(by=['sex', 'day'])['tip'].sum()
# Out:
# sex     day
# Male    Thur     89.41
#         Fri      26.93
#         Sat     181.95
#         Sun     186.78
# Female  Thur     82.42
#         Fri      25.03
#         Sat      78.45
#         Sun      60.61
# Name: tip, dtype: float64

# %% [markdown]
# Again, the total of males tips were higher each day. A big dip for both on Friday and males significantly larger at the weekend than the females.

# %%
# The total spent each meal time, each day by each sex
tips.groupby(by=['sex', "time", 'day'])['total_bill'].sum()
# Out:
# sex     time    day
# Male    Lunch   Thur     561.44
#                 Fri       34.16
#         Dinner  Fri      164.41
#                 Sat     1227.35
#                 Sun     1269.46
# Female  Lunch   Thur     516.11
#                 Fri       55.76
#         Dinner  Thur      18.78
#                 Fri       71.55
#                 Sat      551.05
#                 Sun      357.70
# Name: total_bill, dtype: float64

# %% [markdown]
# There is no data for lunch on Saturday or Sunday.  Males spent more on lunch on Thursday with females spending more on Friday but the figure is way lower than Thursday.  As there is only two days of lunch spends and tips, and with such a discrepancy in total amount in spent, I would think it is not good enough to model data on by itself.  There are no dinner figures for males on Thursday.  And only a small amount spent on Thursday by females.  Males spent more on the remaining days.

# %%
# Total daily tip, by each sex for each meal
tips.groupby(by=['sex', "time", 'day'])['tip'].sum()
# Out:
# sex     time    day
# Male    Lunch   Thur     89.41
#                 Fri       5.70
#         Dinner  Fri      21.23
#                 Sat     181.95
#                 Sun     186.78
# Female  Lunch   Thur     79.42
#                 Fri      10.98
#         Dinner  Thur      3.00
#                 Fri      14.05
#                 Sat      78.45
#                 Sun      60.61
# Name: tip, dtype: float64

# %% [markdown]
# Males gave more tips for lunch on Thursday but not Friday.   There are no figures for males on Thursday dinner.  But for the remining dinner days they out tipped the women.

# %%
# The total of the tips column rounded to two decimal places
Total = df['tip'].sum()
print (round(Total,2))
# Out:
# 731.58

# %%
tips.groupby(by=['day']).sum()
# Out:
#       total_bill     tip  size
# day
# Thur     1096.33  171.83   152
# Fri       325.88   51.96    40
# Sat      1778.40  260.40   219
# Sun      1627.16  247.39   216

# %%
# Show the percentage of total tips Thursday gave
print (round(171.83 / 731.58 * 100,2))
# Out:
# 23.49

# %%
# Percentage of tips from Friday
print  (round(51.96 / 731.58 * 100,2))
# Out:
# 7.1

# %%
# Percentage of tips from Saturday
print  (round(260.40 / 731.58 * 100,2))
# Out:
# 35.59

# %%
# Percentage of tips from Sunday
print  (round(247.39 / 731.58 * 100,2))
# Out:
# 33.82

# %% [markdown]
# Saturdays tips accounted for almost 36% of his overall tips, Sunday was almost 34%, Thursday was almost 23.5% and Friday was only 7%.

# %%
# What were the busiest days, do a count for each day
df.groupby('day').count()
# Out:
#       total_bill  tip  sex  smoker  time  size
# day
# Fri           19   19   19      19    19    19
# Sat           87   87   87      87    87    87
# Sun           76   76   76      76    76    76
# Thur          62   62   62      62    62    62

# %% [markdown]
# Saturday was the busiest day with 87 tables served, followed by Sunday then Thursday and finally Friday.

# %%
# What were the busiest days, do a count for each day
df.groupby('day').count()
# Out:
#       total_bill  tip  sex  smoker  time  size
# day
# Fri           19   19   19      19    19    19
# Sat           87   87   87      87    87    87
# Sun           76   76   76      76    76    76
# Thur          62   62   62      62    62    62

# %%
# Taking the total of each day, get the percentage of each tip. Tip divided by total bill and multiply by 100
df2=df.groupby('day').sum() # sum per day
df2.drop('size',inplace=True,axis=1) # sum of size column is not relevant
df2['percent'] = df2['tip']/df2['total_bill']*100 # add percents
print (df2)
# Out:
#       total_bill     tip    percent
# day
# Fri       325.88   51.96  15.944519
# Sat      1778.40  260.40  14.642375
# Sun      1627.16  247.39  15.203791
# Thur     1096.33  171.83  15.673201

# %% [markdown]
# Even though Friday had the least amount of tables, overall it gave the greatest return on tips. Followed by Thursday, then Sunday. Saturday gave the least percentage of tips.  Tips were about 15% of the bill.

# %%
# Break the information down into smokers and non smokers.  Calculate their total bill, tip and percentage.
df3=df.groupby('smoker').sum()
df3['percent'] = df3['tip']/df3['total_bill']*100
print (df3)
# Out:
#         total_bill     tip  size    percent
# smoker
# No         2897.43  451.77   403  15.592094
# Yes        1930.34  279.81   224  14.495374

# %% [markdown]
# Non smokers spent more and gave better tips.

# %%
# Group the information by day and size of table. Then calculate the tip percentage
df4= df.groupby(['day','size']).sum()
df4['percent'] = df4['tip']/df4['total_bill']*100
df4.dropna() # drop null rows
# Out:
#            total_bill     tip    percent
# day  size
# Fri  1           8.58    1.92  22.377622
#      2         261.15   42.31  16.201417
#      3          15.98    3.00  18.773467
#      4          40.17    4.73  11.774956
# Sat  1          10.32    2.00  19.379845
#      2         892.37  133.43  14.952318
#      3         459.17   68.36  14.887732
#      4         388.39   53.61  13.803136
#      5          28.15    3.00  10.657194
# Sun  2         684.84  109.86  16.041703
#      3         332.76   46.81  14.067196
#      4         480.39   73.58  15.316722
#      5          81.00   12.14  14.987654
#      6          48.17    5.00  10.379905
# Thur 1          10.07    1.83  18.172790
#      2         727.53  117.24  16.114799
#      3          76.64   10.77  14.052714
#      4         149.75   21.09  14.083472
#      5          41.19    5.00  12.138869
#      6          91.15   15.90  17.443774

# %% [markdown]
# Smaller tables give a larger tip percentage.

# %%
# Take and show each time from the dataframe
df["time"]
# Out:
# 0      Dinner
# 1      Dinner
# 2      Dinner
# 3      Dinner
# 4      Dinner
# 5      Dinner
# 6      Dinner
# 7      Dinner
# 8      Dinner
# 9      Dinner
# 10     Dinner
# 11     Dinner
# 12     Dinner
# 13     Dinner
# 14     Dinner
# 15     Dinner
# 16     Dinner
# 17     Dinner
# 18     Dinner
# 19     Dinner
# 20     Dinner
# 21     Dinner
# 22     Dinner
# 23     Dinner
# 24     Dinner
# 25     Dinner
# 26     Dinner
# 27     Dinner
# 28     Dinner
# 29     Dinner
#         ...
# 214    Dinner
# 215    Dinner
# 216    Dinner
# 217    Dinner
# 218    Dinner
# 219    Dinner
# 220     Lunch
# 221     Lunch
# 222     Lunch
# 223     Lunch
# 224     Lunch
# 225     Lunch
# 226     Lunch
# 227    Dinner
# 228    Dinner
# 229    Dinner
# 230    Dinner
# 231    Dinner
# 232    Dinner
# 233    Dinner
# 234    Dinner
# 235    Dinner
# 236    Dinner
# 237    Dinner
# 238    Dinner
# 239    Dinner
# 240    Dinner
# 241    Dinner
# 242    Dinner
# 243    Dinner
# ...

# %%
# Another way to display the above information. No need for this, just practicing different ways to view the information.
variable["time"]
# Out:
# 0      Dinner
# 1      Dinner
# 2      Dinner
# 3      Dinner
# 4      Dinner
# 5      Dinner
# 6      Dinner
# 7      Dinner
# 8      Dinner
# 9      Dinner
# 10     Dinner
# 11     Dinner
# 12     Dinner
# 13     Dinner
# 14     Dinner
# 15     Dinner
# 16     Dinner
# 17     Dinner
# 18     Dinner
# 19     Dinner
# 20     Dinner
# 21     Dinner
# 22     Dinner
# 23     Dinner
# 24     Dinner
# 25     Dinner
# 26     Dinner
# 27     Dinner
# 28     Dinner
# 29     Dinner
#         ...
# 214    Dinner
# 215    Dinner
# 216    Dinner
# 217    Dinner
# 218    Dinner
# 219    Dinner
# 220     Lunch
# 221     Lunch
# 222     Lunch
# 223     Lunch
# 224     Lunch
# 225     Lunch
# 226     Lunch
# 227    Dinner
# 228    Dinner
# 229    Dinner
# 230    Dinner
# 231    Dinner
# 232    Dinner
# 233    Dinner
# 234    Dinner
# 235    Dinner
# 236    Dinner
# 237    Dinner
# 238    Dinner
# 239    Dinner
# 240    Dinner
# 241    Dinner
# 242    Dinner
# 243    Dinner
# ...

# %%
# Show each sex of the customer along with the time they ate. This information has no bearing on the assignment other than my wanting to see how the information can be displayed using different parameters.

variable[["sex", "time"]]
# Out:
#         sex    time
# 0    Female  Dinner
# 1      Male  Dinner
# 2      Male  Dinner
# 3      Male  Dinner
# 4    Female  Dinner
# 5      Male  Dinner
# 6      Male  Dinner
# 7      Male  Dinner
# 8      Male  Dinner
# 9      Male  Dinner
# 10     Male  Dinner
# 11   Female  Dinner
# 12     Male  Dinner
# 13     Male  Dinner
# 14   Female  Dinner
# 15     Male  Dinner
# 16   Female  Dinner
# 17     Male  Dinner
# 18   Female  Dinner
# 19     Male  Dinner
# 20     Male  Dinner
# 21   Female  Dinner
# 22   Female  Dinner
# 23     Male  Dinner
# 24     Male  Dinner
# 25     Male  Dinner
# 26     Male  Dinner
# 27     Male  Dinner
# 28     Male  Dinner
# 29   Female  Dinner
# ..      ...     ...
# 214  Female  Dinner
# 215  Female  Dinner
# 216    Male  Dinner
# 217    Male  Dinner
# 218    Male  Dinner
# 219  Female  Dinner
# 220    Male   Lunch
# 221  Female   Lunch
# 222    Male   Lunch
# 223  Female   Lunch
# 224    Male   Lunch
# 225  Female   Lunch
# 226  Female   Lunch
# ...

# %%
# Show lines 2 to 4. 
variable[2:5]
# Out:
#    total_bill   tip     sex smoker  day    time  size_of_party
# 2       21.01  3.50    Male     No  Sun  Dinner              3
# 3       23.68  3.31    Male     No  Sun  Dinner              2
# 4       24.59  3.61  Female     No  Sun  Dinner              4

# %%
# Looking at the total bill and tip section.
variable [["total_bill", "tip"]]
# Out:
#      total_bill   tip
# 0         16.99  1.01
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 4         24.59  3.61
# 5         25.29  4.71
# 6          8.77  2.00
# 7         26.88  3.12
# 8         15.04  1.96
# 9         14.78  3.23
# 10        10.27  1.71
# 11        35.26  5.00
# 12        15.42  1.57
# 13        18.43  3.00
# 14        14.83  3.02
# 15        21.58  3.92
# 16        10.33  1.67
# 17        16.29  3.71
# 18        16.97  3.50
# 19        20.65  3.35
# 20        17.92  4.08
# 21        20.29  2.75
# 22        15.77  2.23
# 23        39.42  7.58
# 24        19.82  3.18
# 25        17.81  2.34
# 26        13.37  2.00
# 27        12.69  2.00
# 28        21.70  4.30
# 29        19.65  3.00
# ..          ...   ...
# 214       28.17  6.50
# 215       12.90  1.10
# 216       28.15  3.00
# 217       11.59  1.50
# 218        7.74  1.44
# 219       30.14  3.09
# 220       12.16  2.20
# 221       13.42  3.48
# 222        8.58  1.92
# ...

# %%
# Experimenting with the loc function to look at the time of each meal. Again, no purpose, just for my own curiosity.
variable.loc[:,"time"]
# Out:
# 0      Dinner
# 1      Dinner
# 2      Dinner
# 3      Dinner
# 4      Dinner
# 5      Dinner
# 6      Dinner
# 7      Dinner
# 8      Dinner
# 9      Dinner
# 10     Dinner
# 11     Dinner
# 12     Dinner
# 13     Dinner
# 14     Dinner
# 15     Dinner
# 16     Dinner
# 17     Dinner
# 18     Dinner
# 19     Dinner
# 20     Dinner
# 21     Dinner
# 22     Dinner
# 23     Dinner
# 24     Dinner
# 25     Dinner
# 26     Dinner
# 27     Dinner
# 28     Dinner
# 29     Dinner
#         ...
# 214    Dinner
# 215    Dinner
# 216    Dinner
# 217    Dinner
# 218    Dinner
# 219    Dinner
# 220     Lunch
# 221     Lunch
# 222     Lunch
# 223     Lunch
# 224     Lunch
# 225     Lunch
# 226     Lunch
# 227    Dinner
# 228    Dinner
# 229    Dinner
# 230    Dinner
# 231    Dinner
# 232    Dinner
# 233    Dinner
# 234    Dinner
# 235    Dinner
# 236    Dinner
# 237    Dinner
# 238    Dinner
# 239    Dinner
# 240    Dinner
# 241    Dinner
# 242    Dinner
# 243    Dinner
# ...

# %% [markdown]
# Boolean Selects (or logical expression) evaluates to one of two states true or false. Python provides the boolean type that can be either set to False or True. Many functions and operations returns boolean objects.
#
# The not keyword can also be used to inverse a boolean type.
# https://thomas-cokelaer.info/tutorials/python/boolean.html

# %%
# Using boolean selects to see if the sex of the customer was female. True means they were. False indicates they were male, as that is the only other option. No need for this. Just trying it out to see how it works.
variable.loc [:, "sex"] == "Female"
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11      True
# 12     False
# 13     False
# 14      True
# 15     False
# 16      True
# 17     False
# 18      True
# 19     False
# 20     False
# 21      True
# 22      True
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29      True
#        ...
# 214     True
# 215     True
# 216    False
# 217    False
# 218    False
# 219     True
# 220    False
# 221     True
# 222    False
# 223     True
# 224    False
# 225     True
# 226     True
# 227    False
# 228    False
# 229     True
# 230    False
# 231    False
# 232    False
# 233    False
# 234    False
# 235    False
# 236    False
# 237    False
# 238     True
# 239    False
# 240     True
# 241    False
# 242    False
# 243     True
# Name: sex, Length: 244, dtype: bool

# %%
#  Only select the rows that have the information set to female. == is a test to see if the information is equal to female. df.loc is taking a load of true or false values and selecting the rows that are true.
variable.loc [variable.loc [:, "sex"] == "Female"]
# Out:
#      total_bill   tip     sex smoker   day    time  size_of_party
# 0         16.99  1.01  Female     No   Sun  Dinner              2
# 4         24.59  3.61  Female     No   Sun  Dinner              4
# 11        35.26  5.00  Female     No   Sun  Dinner              4
# 14        14.83  3.02  Female     No   Sun  Dinner              2
# 16        10.33  1.67  Female     No   Sun  Dinner              3
# 18        16.97  3.50  Female     No   Sun  Dinner              3
# 21        20.29  2.75  Female     No   Sat  Dinner              2
# 22        15.77  2.23  Female     No   Sat  Dinner              2
# 29        19.65  3.00  Female     No   Sat  Dinner              2
# 32        15.06  3.00  Female     No   Sat  Dinner              2
# 33        20.69  2.45  Female     No   Sat  Dinner              4
# 37        16.93  3.07  Female     No   Sat  Dinner              3
# 51        10.29  2.60  Female     No   Sun  Dinner              2
# ...

# %%
# Only select those who ate on Friday
variable.loc [variable.loc [:, "day"] == "Fri"]
# Out:
#      total_bill   tip     sex smoker  day    time  size_of_party
# 90        28.97  3.00    Male    Yes  Fri  Dinner              2
# 91        22.49  3.50    Male     No  Fri  Dinner              2
# 92         5.75  1.00  Female    Yes  Fri  Dinner              2
# 93        16.32  4.30  Female    Yes  Fri  Dinner              2
# 94        22.75  3.25  Female     No  Fri  Dinner              2
# 95        40.17  4.73    Male    Yes  Fri  Dinner              4
# 96        27.28  4.00    Male    Yes  Fri  Dinner              2
# 97        12.03  1.50    Male    Yes  Fri  Dinner              2
# 98        21.01  3.00    Male    Yes  Fri  Dinner              2
# 99        12.46  1.50    Male     No  Fri  Dinner              2
# 100       11.35  2.50  Female    Yes  Fri  Dinner              2
# 101       15.38  3.00  Female    Yes  Fri  Dinner              2
# 220       12.16  2.20    Male    Yes  Fri   Lunch              2
# ...

# %%
# Only select those who ate on Thursday.  This is just to satisfy my own curiosity when trying out different things. Even though I may not use them in this assignment it will be good for future assignments to know how to do this.
variable.loc [variable.loc [:, "day"] == "Thur"]
# Out:
#      total_bill   tip     sex smoker   day    time  size_of_party
# 77        27.20  4.00    Male     No  Thur   Lunch              4
# 78        22.76  3.00    Male     No  Thur   Lunch              2
# 79        17.29  2.71    Male     No  Thur   Lunch              2
# 80        19.44  3.00    Male    Yes  Thur   Lunch              2
# 81        16.66  3.40    Male     No  Thur   Lunch              2
# 82        10.07  1.83  Female     No  Thur   Lunch              1
# 83        32.68  5.00    Male    Yes  Thur   Lunch              2
# 84        15.98  2.03    Male     No  Thur   Lunch              2
# 85        34.83  5.17  Female     No  Thur   Lunch              4
# 86        13.03  2.00    Male     No  Thur   Lunch              2
# 87        18.28  4.00    Male     No  Thur   Lunch              2
# 88        24.71  5.85    Male     No  Thur   Lunch              2
# 89        21.16  3.00    Male     No  Thur   Lunch              2
# ...

# %%
# A short summary of the data frame
variable.describe()
# Out:
#        total_bill         tip  size_of_party
# count  244.000000  244.000000     244.000000
# mean    19.785943    2.998279       2.569672
# std      8.902412    1.383638       0.951100
# min      3.070000    1.000000       1.000000
# 25%     13.347500    2.000000       2.000000
# 50%     17.795000    2.900000       2.000000
# 75%     24.127500    3.562500       3.000000
# max     50.810000   10.000000       6.000000

# %% [markdown]
# 244 bills and 244 tips so there was a tip left with each meal.

# %%
# A short summary of the data frame for female customers only
(variable.loc [variable.loc [:, "sex"] == "Female"]).describe()
# Out:
#        total_bill        tip  size_of_party
# count   87.000000  87.000000      87.000000
# mean    18.056897   2.833448       2.459770
# std      8.009209   1.159495       0.937644
# min      3.070000   1.000000       1.000000
# 25%     12.750000   2.000000       2.000000
# 50%     16.400000   2.750000       2.000000
# 75%     21.520000   3.500000       3.000000
# max     44.300000   6.500000       6.000000

# %%
# A short summary of the data frame for male customers only
(variable.loc [variable.loc [:, "sex"] == "Male"]).describe()
# Out:
#        total_bill         tip  size_of_party
# count  157.000000  157.000000     157.000000
# mean    20.744076    3.089618       2.630573
# std      9.246469    1.489102       0.955997
# min      7.250000    1.000000       1.000000
# 25%     14.000000    2.000000       2.000000
# 50%     18.350000    3.000000       2.000000
# 75%     24.710000    3.760000       3.000000
# max     50.810000   10.000000       6.000000

# %%
# Female vs males for various graphs.  This created an error message which was then corrected in a subsequent revision by the programme. So I created the below as it did not cause an error message.
import seaborn as sns
sns.pairplot (variable, hue="sex")
# Out:
# C:\Users\Rebecca\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# FacetGrid allows visualisation along 3 dimensions, row, col and hue.  Visualisation of the distribution of one variable and relationship between multiple variables within panels. I breakdown the information on the graphs further down the page.

# %%
# As above but did not cause a system error message when ran.
sns.pairplot(df, "sex")

# %%
g = sns.pairplot(tips[["tip", "total_bill", "sex", "day"]], hue="day", diag_kind="hist")
 
for ax in g.axes.flat: 
    plt.setp(ax.get_xticklabels(), rotation=45)

# %% [markdown]
# The information is too dense and impossible at times to differentiate between the different days as some are hidden behind others.  Not a good option for this information.

# %%
g = sns.pairplot(tips[[ "total_bill", "sex", "day", "tip"]], hue="sex", diag_kind="hist")
 
for ax in g.axes.flat: 
    plt.setp(ax.get_xticklabels(), rotation=45)

# %% [markdown]
# Less variables make it easier to see the differences between the sexs rather than days of the week.

# %%
g = sns.pairplot(tips[["tip",  "total_bill", "sex", "time", "smoker", "day"]], hue="day", diag_kind="hist")
g.map_upper(sns.regplot) 
g.map_lower(sns.residplot) 
g.map_diag(plt.hist) 
for ax in g.axes.flat: 
    plt.setp(ax.get_xticklabels(), rotation=45) 
    
g.add_legend() 
g.set(alpha=.5)

# %% [markdown]
# The third plot here proves the most useful but still is not very clear.  There seems to be a lot of information for Sunday but it is hard to know if that is the case or the colour red takes over and blots out the others.

# %% [markdown]
# #### Summary so far

# %% [markdown]
# Descriptive information in the form of tables can show a lot of information but graphs and plots make certain things clearer, rather than wading thought lines and lines of text. e.g. It may not have been initially obvious that there were no tips recorded for lunchtime Saturday or Sunday as there were no diners.  There were no unaccompanied diners on Sunday.  There were no tips recorded on Thursday dinner for males.  The Saturday has the most tips (260.39 or approx. 36% of the total tips for the four days) and the day with the least amount of tips is Friday (51.98 or 7% of the total tips).

# %% [markdown]
# ## Regression

# %% [markdown]
# Linear regression predicts relationships between variables using statistics.  Fitting lines to datasets.  One of the easier to understand is linear regression.  Two related variables are taken and we try to find a linear function to estimate and explain the relationship between one dependent variable (total bill) and one or more independent variables.  Can the tip amount be predicted basing it on the total bill paid by the customer.

# %%
# Plot data and a linear regression model fit.
sns.relplot(x="total_bill", y="tip", data=tips);

# %%
sns.regplot(x="total_bill", y="tip", data=tips);

# %%
# Below is the same data but this time implot is used.  Implot uses regplot and facetgrid.  
sns.lmplot(x="total_bill", y="tip", data=tips);

# %% [markdown]
# The three plots show the exact same information but the last two have a grid and creates a line going through it making it easier to visualise the information and see if the data is a fit for a linear regression model.

# %% [markdown]
# There appears to be some correlation between tips and total bill as there are no outlying values in the upper triangle while the lower triangle does have a few but overall the greatest concentration seems to be going in a line and does not appear to be totally random.  Without knowing any other information and just looking at the plots we can see that the highest bill resulted in the highest tip.  Lower bill totals seem to result in lower tip amounts also.

# %%
# Regression plots using FacetGrid broken into individual days
g = sns.FacetGrid(df, col="day") 
g.map(sns.regplot, "total_bill", "tip") 
plt.xlim(0, 55) 
plt.ylim(0, 10)
# Out:
# (0, 10)

# %% [markdown]
# On Thursday the values are more clustered towards the bottom of the grid meaning the total bill cost was lower and the tips followed suit. Friday doesn’t have as many data points but the ones that are there fit the line better. Saturday shows a lot of activity in the bottom half with most points congregating to the line or nearby but a few of the tips and total bill points are on the higher side and appear at the top right corner of the plot. Sunday has the greatest spread away from the mean but the points stay more towards the middle with less on the bottom and the top of the line.
#
#
# Looking at the plots it appears that there were more points on Saturday. The less amounts stay fairly close to the line but as the amount on the total bill increases so does the value of the tips. It would appear that Saturday would be the best day to work in the restaurant for higher tips but that doesn’t say whether it was lunch time or dinner time. It is also fair to say that the information is skewed as there was no lunch tips recorded Saturday or Sunday. And there was no Thursday dinner data recorded for males.

# %%
# Regression plots using FacetGrid broken down by sex
g = sns.FacetGrid(df, col="sex") 
g.map(sns.regplot, "total_bill", "tip") 
plt.xlim(0, 50) 
plt.ylim(0, 10)
# Out:
# (0, 10)

# %% [markdown]
# Just taking a quick look at the total bill and tip separated by the sex of the customer. There are a lot more points for males. We have already seen from the descriptive data earlier that there are 157 males and 87 females which is also reflected here. The female customers tend to stay more on the line with a greater concentration at the 10 to 20 spend. Males also tend to stay nearer the line at the start but as it progresses the bills and tips seem to spread out. From a glance it seems the greatest concentration is from 10 to 30 spend also.

# %%
# A scatter plot showing each daily total bill and what meal time it refers to
sns.catplot(x="day", y="total_bill", hue='time', data=tips)

# %% [markdown]
# It is easy to see from above that the data points for Thursday relate almost exclusively to lunch time.  Friday has a very low amount of points over all for the day with more than half relating to dinner.  Saturday and Sunday are exclusively dinner time only. Both have a high concentration from the 10 dollar spend which only begins to noticeably taper off once it gets above 30.  The highest tip of the four days was given on a Saturday.

# %%
# Scatter plot showing which sex paid the most daily.
sns.catplot(x="day", y="total_bill", hue='sex', data=tips)

# %% [markdown]
# There seems to be a good split between males and females on Thursday with females tending to congregate around the 10 to 20 spend range. Friday seems to have a slightly larger number of males. Both Saturday and Sunday seem to have a greater concentration of males. We can see from the above that males tend to spend higher amounts for 3 out of the 4 days.  The highest tip amount on Saturday was given by a male.  As we know there was no lunch sittings on Saturday we can say it was given at dinner time.

# %%
# Same as plot above but this time broken down into the different meal times.
sns.catplot(x="day", y="total_bill", col="time", hue='sex', data=tips)

# %% [markdown]
# Thursday lunch seems to have an equal amount of most sexes with females congregating more in the mid-teen range and males slightly higher. Friday lunch time has very little data with just a single point more for males recorded than females. There is no data for Saturday or Sunday. Dinner time Thursday recorded just a single instance and it was female. Friday had some more data with both sexes looking even. Males tend to spend more. Saturday and Sunday dinner records a lot more of a male populating attending. This could reflect why there were such a greater number of males 157 to females 87 initially. Again, males are spending more.

# %%
sns.catplot(data=tips, x="total_bill", y="tip")

# %%
# Each bill and tip.  It is hard to get much information from this other than the spread of the total bill and tip. 
sns.relplot(x="total_bill", y="tip", data=tips);

# %%
# Same graph as above but now differentiated by sex of customer
sns.relplot(x="total_bill", y="tip", hue="day",data=tips);

# %% [markdown]
# The above has too many variables in the hue making it difficult to read. It will look better with less information.

# %%
# Days of the week compared to the times the meals were served. Again it looks overcomplicated and hard to focus on any particulat data.
sns.relplot(x="total_bill", y="tip", col="time",
                   hue="day", data=tips);

# %%
# Total bill and tip by each sex
sns.relplot(x="total_bill", y="tip", hue="sex",data=tips);

# %% [markdown]
# Provides a good starting point.  There are a lot more data points for males. And they tend to go higher.

# %%
# Each meal and tip broken down by meal times.
sns.relplot(x="total_bill", y="tip", hue="time",data=tips);

# %% [markdown]
# Looking at the two above graphs it becomes apparent that the total bill and corresponding tips are higher at dinner.

# %%
# Each bill and tip for each meal time and split between smokers and non smokers
sns.relplot(x="total_bill", y="tip", col="smoker", hue="time",data=tips);

# %% [markdown]
# The non-smokers total bill and tips are more linear and follow a straighter line when compared to the smokers which are much more widely dispersed. The non-smokers have an easier to see correlation between the total bill and tip.

# %%
sns.lmplot(x="total_bill", y="tip", hue="smoker", data=tips)

# %% [markdown]
# The above plot shows both the non-smokers and the smokers but the regression lines demonstrates more clearly how the data points align along it. The non-smokers line is steeper with most of the points in the lower half staying quite close to their line (they spend more than the smokers) but veering away from it at the higher points showing higher than expected tips with high bills. The smoker’s line does not have the same scatter with points further away from the line as the total bill amount increases with lower than expected tips in some cases and higher in others.

# %%
# Each meal time, each sex, whether they were smokers or not and how much the meal cost and the tip given 
sns.relplot(x="total_bill", y="tip", col="smoker", style="sex", hue="time",data=tips);

# %% [markdown]
# Adding a new variable to the above information, time, the more linear pattern of tips vs total cost is again repeated for the non-smokers and the same random scatter is also there for the smokers.  So regardless of the meal time, the correlation between total cost and tips remains constant.

# %%
sns.scatterplot(x="total_bill", y="tip", hue="size", style="smoker", data=tips);

# %% [markdown]
# The above scatterplot shows the distribution of the total bill and the corresponding tip value differentiated by the different group sizes and whether they are smokers or not. The above shows mostly groups of 2, it is hard to see if there are more smokers than non-smokers. As the values go further out it appears non-smokers are spending more than smokers and paying correspondingly higher tips. The smokers who are paying larger bills tips aren’t as high. The bigger bills also appear to belong to groups of 4 or 6. A smoker gave the largest tip amount of the four days.  As discussed previously it was on a Saturday dinner time by a male.

# %%
# scatter to g.map instructs seaborn to apply scatter function to the selected segments.
g = sns.FacetGrid(df, col="day", hue="sex") 
g.map(plt.scatter, "total_bill", "tip")

# %% [markdown]
# Even though the legend is not shown here, I know from the previous plots and graphs that a male was the highest tipper. So, looking at the highest tipper here which is blue, I can surmise that blue is for males and orange is females. The above graphs are very similar to the scatter plots already described further up. I only used these to see how they look when compared to the scatterplots. The scatter plots are probably better in that they detail the legend on the side.

# %%
g = sns.JointGrid(x="total_bill", y="tip", data=df) 
g.plot_joint(sns.regplot, order=2) 
g.plot_marginals(sns.distplot)

# %% [markdown]
# JointGrid gives a better picture by allowing marginal and joint data separately.

# %%
sns.jointplot(x="total_bill", y="tip", 
              kind="reg", # Options are "scatter", "reg", "resid", "kde", "hex"
              data=tips)

# %% [markdown]
# I prefer jointplot as opposed to JointGrid as the lines make it easier to look at the data and formulate opinions based on the graph.  Jointplot looks at just one relationship while pairplot shows all relationships pairwise.

# %%
sns.jointplot(x="size", y="tip", 
              kind="reg", # Options are "scatter", "reg", "resid", "kde", "hex"
              data=tips)

# %% [markdown]
# From the above, there doesn’t seem to be to be a correlation between the size of the group and the tip paid. The points are not congregating along the line like in the plot above for total bill and tip.

# %%
sns.pairplot(df, "sex")

# %% [markdown]
# There are two types of plots here. Diagonally is a kernel density function. The blue relates to males. The very first plot shows that for males the majority of the bill total is between approx 0 and 60. Coming down from the top of the curve is just under 20 is the typical bill total. The spread for the females is broadly the same but the peak is higher. The next diagonal one down relates to tip and again that is broadly the same for male and females. The final one relates to the size of the party. Again, they are broadly the same for males and females with one bump near the end for the males at 4 showing there was a higher incidence of male party size of 4 than females.
# The rest of the plots are scatter plots. I have described most of them already further up.

# %%
# Here is the regression from earlier showing the relationship between tip and total_bill
sns.regplot(x="total_bill", y="tip", data=tips);
# Out:
# C:\Users\Rebecca\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# According to the Tip and Total bill distribution, we can find out the linear relationship between those values. Thus we can predict the amount of tip (output) based on the total bill that customers have paid (dependent variable).  How good of a regression model is it?  The RMSD is an indicator of difference between predicted and actual values.  https://www.codeastar.com/regression-model-rmsd/  RMSD is always non-negative, and a value of 0 (almost never achieved in practice) would indicate a perfect fit to the data. In general, a lower RMSD is better than a higher one.

# %%
# Using the Root-Mean-Square Deviation (RMSD), first 200 records are learning and remaining are testing values.
learning_x = df[['total_bill', 'size']].values [:200]
learning_y = df['tip'].values [:200]
testing_x = df[['total_bill', 'size']].values[-44:]
testing_y = df['tip'].values[-44:]

# %%
# Use the Linear Regression model.
from sklearn.linear_model import LinearRegression
lreg = LinearRegression()
lreg.fit(learning_x, learning_y)
prediction = lreg.predict(testing_x)

# %%
# Compare predicted output with actual
import pandas as pd
df_output_compare = pd.DataFrame({'predicted':prediction, 'actual':testing_y})
sns.regplot(x="actual", y="predicted", data=df_output_compare)
plt.show()
# Out:
# C:\Users\Rebecca\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# Only 2 features are used to predict the tip outcome, the predicted values are hard to correlate to actual ones.  The sklearn library provides a mean_squared_error function which helps to find the MSE of RMSE(RMSD). Then apply a square root on the MSE to get RMSD.
from sklearn.metrics import mean_squared_error
from math import sqrt
rmsd = sqrt(mean_squared_error(testing_y, prediction))
print(rmsd)
# Out:
# 1.189772487870686

# %%
# Another learning set but from the first 5 records from the df
learning_x_5 = df[['total_bill', 'size']].values [:5]
learning_y_5 = df['tip'].values [:5]

# %%
# New prediction
lreg.fit((learning_x_5), learning_y_5)
prediction_5 = lreg.predict(testing_x)

# %%
# Use new prediction to compare with the actual output.
df_output_compare_5 = pd.DataFrame({'predicted':prediction_5, 'actual':testing_y})
sns.regplot(x="actual", y="predicted", data=df_output_compare_5, color="g")
plt.show()

# %%
# Calculate the new RMSD
rmsd_5 = sqrt(mean_squared_error(testing_y, prediction_5))
print(rmsd_5)
# Out:
# 1.3766746955609788

# %% [markdown]
# a A perfect model means a 0 in RMSD and a less effective model means a larger RMSD.  As expected, there is a larger RMSD for a less effective model.

# %% [markdown]
# ## Summary of this section

# %% [markdown]
# Overall there does seem to be a correlation between total bill amount and tip.  As a customer's total bill increases so does the tip.  Males tend to spend more and tip higher.  Females follow the regression line better than males for total bill and tips.

# %% [markdown]
# ## Analyse

# %%
# Using seaborn's facetgrid looking at tip percentage for different serving times for each sex.  linespace evenly spaces the numbers.
tips['tip_pct'] = 100 * tips['tip'] / tips['total_bill']

grid = sns.FacetGrid(tips, row="sex", col="time", margin_titles=True)
grid.map(plt.hist, "tip_pct", bins=np.linspace(0, 35, 35), color="r" );

# %% [markdown]
#  Lunch time, percentage wise, tips are broadly similar with both the male and females.  Dinner time is quite different with the males giving far higher percentages.
#
#  Lunch time females have higher peaks with the most of the tips falling between 12 to 21% and peaking at approximately 15%.  Male lunch diners’ tips were mostly between 8% and 28% and less high peaks.  Dinner time males had a far greater amount of time for much larger amounts.

# %%
# Tip percentage for the different meal times for each day this time looking at whether the customers were smokers or not.
tips['tip_pct'] = 100 * tips['tip'] / tips['total_bill']

grid = sns.FacetGrid(tips, row="day", col="smoker", margin_titles=True)
grid.map(plt.hist, "tip_pct", bins=np.linspace(0, 35, 35), color="b" );

# %% [markdown]
# Countplot relates to barplot which shows the information in rectangle shapes and the length relates to the data in the category selected. The higher the rectangle, the greater the porportion of the category within the data. With countplot, the numbers are directly related to the observations of the data rather than the proportion.
# Thursday non-smokers gave a higher percentage of tips, on Friday smokers were more generous with the tips. Saturday non-smokers had higher peaks but they were a bit more scattered than the smokers which seemed a bit steadier. Sunday non-smokers gave a far higher tip percentage compared to smokers.

# %%
dataset5 = df[["total_bill", "tip"]]
dataset5.plot()

# %% [markdown]
# The above output shows the line plot for the total bill and tips column.  Where the total line spikes there often is a corresponding spike on the tip line.

# %%
dataset5 = df[["total_bill", "tip", "size"]]
dataset5.plot()

# %% [markdown]
# The output above now includes the side of the party.  Although it is small and difficult to see, the spikes for the party size seem to occur at the same places tip and total bill.  This suggests that the size of the party can have an impact on the total bill and the resulting tip.

# %%
tips.head()

tips['tip_pct'] = 100 * tips['tip'] / tips['total_bill']
grid = sns.FacetGrid(tips, row="size", col = "sex",  margin_titles=True)
grid.map(plt.hist, "tip_pct", bins=np.linspace(0, 40, 15));

# %% [markdown]
# There was a very small amount of single male groups. Of the (possibly) one recorded, the tip percentage was just over 20%. Female single groups had a wider scope going from just over 10% to just over 30%.
# There was a lot more data recorded for groups of 2. Male groups of 2 is by far the most common combination and their tip percentage starts at around 5% and goes to just over 30%, and the peak at approximately 15%. Female groups of 2 is the second most common combination whose tipping percentage goes from 5% to just below 30% and the peak approximately 15% also. Male groups of 3 tips began at approximately 8% and went to just over 20%. Females of 3 began in the mid-single digit percentage and continued to mid-20%. Male groups of 4 began tips at 7%, were strongest between 13 to 20% and then dropped off at 28%. Females of 4 began at 9% and finished at 17%. There were a few groups of males with 5 in the party. Tips started at 8% and mostly stopped at 15% with a single exception of 24%. There was a single group of females with 5 in the party and their tip was just under 20%. There were 2 instances of male groups with 6 and their tips were 10 and 19%. There were also 2 groups of 6 members in a female party with their tips at 11 and 19%.
#
# Overall it appears smaller tables of 2 are the better tippers.

# %%
# Male smokers & non smokers, female smokers & non smokers counted & plotted
sns.countplot('sex', hue='smoker', data=tips)

# %% [markdown]
# There are more male non-smokers than smokers and the trend continues for females.

# %%
sns.countplot('sex', hue="time", data=tips)

# %% [markdown]
# Most of the males ate at dinnertime but there wasn’t  a large split in the times females attended.

# %%
# A quick count on the amount of covers served each day
sns.countplot('day', data=tips)

# %% [markdown]
# There was approximately 60 people served on Thursday.  This dropped to 20 Friday. Peaked to above 80 on Saturday and slightly fell on Sunday to just below 80.

# %%
# A count on the amount of covers served daily and at what time
sns.countplot('day', hue="time", data=tips)

# %% [markdown]
# Most of the covers which were served on Thursday were at lunchtime except for one.  Friday had a low number served with more at dinner.  Saturday and Sunday were very high and were all dinners.  There were very few dinners served Thursday.  In fact, there was only one which is shown below.

# %%
df.groupby(['day','time']).count()
# Out:
#              total_bill  tip  sex  smoker  size
# day  time
# Fri  Dinner          12   12   12      12    12
#      Lunch            7    7    7       7     7
# Sat  Dinner          87   87   87      87    87
# Sun  Dinner          76   76   76      76    76
# Thur Dinner           1    1    1       1     1
#      Lunch           61   61   61      61    61

# %%
# Tables per day, per size
import seaborn as sb
sb.countplot(x='day', hue='size', data=df)

# %% [markdown]
# Saturday had the most amount of 2 people tables closely followed by Thursday, then Sunday and finally Friday. 2 people tables were the most popular.  3  and 4 people tables were the next popular. There were very few 1, 5 or 6 people tables.

# %%
# Using box plots to look at the total bill but able to see the minimum, first quartile, median, third quartile, and maximum. Shows outliers and what their values are.
sns.set(style="whitegrid")

tips = sns.load_dataset("tips")
sns.boxplot(y=tips["total_bill"])

# %% [markdown]
# Here we can see that the median total bill spent was just below 20. The least amount was just above zero and the max was just above 50. The shaded blue area begins with the first quartile. The black line is the median and the top of the blue box is the third quartile. The median separates the upper half from the lower half. If all the values within the dataset are laid out in order the one in the middle is the median. The first quartile is the median of the values before the median detailed in the lines above here. The third quartile is the median of the values of the area above the median. The interquartile Range begins at the first quartile and ends at the third quartile, taking in the median. The diamond shapes above the upper adjacent value are known as an outliner.

# %%
# Boxplot showing total bill on each day of the week.
sns.boxplot(x="day", y="total_bill", data=tips)

# %%
# Total bill, each day by sex
sns.boxplot(x="day", y="total_bill", hue="sex", data=tips)

# %% [markdown]
# Above is a box plot of the total bill each day sub divided by gender. Thursday shows that males spent more, Friday was the same. Saturday was a little more equal but the outliners belonged to the males and the same on Sunday.

# %%
sns.boxplot(x="day", y="total_bill", hue="sex", data=tips)
sns.swarmplot(x="day", y="total_bill", hue="sex", data=tips, Color="purple")

# %% [markdown]
# This plot is the same as the one above but this time I have added swarmplot points in order to see the frequency of the data points and where they occur.

# %%
sns.boxplot(x="day", y="total_bill", hue="sex", data=tips)

# %%
# Total bill and sex and if customers were smokers
sns.boxplot(x="smoker", y="total_bill", hue="sex", data=tips)

# %% [markdown]
# The above shows the breakdown between male and female smokers and non-smokers. It shows the same information as earlier but in a different format.

# %%
# I see from the error message when I ran this that it will be depreciated in future use but I wanted to see what it could produce.  The graph is far too tight to make any real sense of. Maybe if I used a section of the information only.
sns.factorplot(data=tips, x="total_bill", y="tip")
# Out:
# C:\Users\Rebecca\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
# The information is far too messy to make much sense of, and it takes a long time for the graphs to render when compared to others such as implot or catplot on my laptop. 
sns.factorplot(data=df, x="total_bill", y="tip", col="day")
# Out:
# C:\Users\Rebecca\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
# A KDE plot is a lot like a histogram, it estimates the probability density of a continuous variable.
plt.figure(figsize=(10,6))
sns.kdeplot(tips['total_bill'], label='Total Bill')
plt.xlabel('Total Bill')
plt.ylabel('Probability Density')
plt.title('Probability density plot of the total bill')
plt.show()

# %% [markdown]
# From the kernel density plot we can see the graph peaks at approximately 15 dollars.  This signifies that most of the bills tend to cost this much.

# %%
# A KDE plot is a lot like a histogram, it estimates the probability density of a continuous variable.
plt.figure(figsize=(10,6))
sns.kdeplot(tips['tip'], label='Tip')
plt.xlabel('Tip')
plt.ylabel('Probability Density')
plt.title('Probability density plot of the tips')
plt.show()

# %% [markdown]
# In this KDE the peak occurs at 2 and begins to decrease rapidly once 4 dollars is reached. This would indicate that most of the tips are between this range.

# %%
df4= df.groupby(['day','size']).sum()
df4['percent'] = df4['tip']/df4['total_bill']*100
print (df4)
# Out:
#            total_bill     tip    percent
# day  size
# Fri  1           8.58    1.92  22.377622
#      2         261.15   42.31  16.201417
#      3          15.98    3.00  18.773467
#      4          40.17    4.73  11.774956
# Sat  1          10.32    2.00  19.379845
#      2         892.37  133.43  14.952318
#      3         459.17   68.36  14.887732
#      4         388.39   53.61  13.803136
#      5          28.15    3.00  10.657194
# Sun  2         684.84  109.86  16.041703
#      3         332.76   46.81  14.067196
#      4         480.39   73.58  15.316722
#      5          81.00   12.14  14.987654
#      6          48.17    5.00  10.379905
# Thur 1          10.07    1.83  18.172790
#      2         727.53  117.24  16.114799
#      3          76.64   10.77  14.052714
#      4         149.75   21.09  14.083472
#      5          41.19    5.00  12.138869
#      6          91.15   15.90  17.443774

# %%
# KDE plots of the tip distribution separated by day
g = sns.FacetGrid(df, col="day") 
g.map(sns.distplot, "tip")

# %% [markdown]
# On Thursday the most common occurrence of tips was approximately just below 2.50 which then declined and stopped at approximately 8 dollars. Friday the tips have a broader tip of the curve meaning more of the tips were between 1 and 4 dollars rather than just a single point as which happened Thursday. Saturday the tips began to climb at under a dollar and dropped significantly before 5 dollars but there were still some instances of tips which came to ten dollars. Sunday the peak was the shortest of the 4 days but broader meaning the tips were more constant. They began to climb at 50 cent and only dropped once it reached 5 dollars.

# %%
sns.distplot(tips["size"], bins=20)

# %% [markdown]
# The above kde plot shows that most of the visits to the restaurant were by groups of 2 as that is where the peak is the largest. The groups of 3 and 4 are the same while groups of 1, 5 and 6 are almost nil and none of the groups reached 7.

# %%
# KDE plots of the tip distribution separated by day and sex
g = sns.FacetGrid(df, col="day", hue="size") 
g.map(sns.distplot, "tip")
# Out:
# C:\Users\Rebecca\Anaconda3\lib\site-packages\numpy\core\_methods.py:140: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# C:\Users\Rebecca\Anaconda3\lib\site-packages\numpy\core\_methods.py:132: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\Rebecca\Anaconda3\lib\site-packages\statsmodels\nonparametric\bandwidths.py:20: RuntimeWarning: invalid value encountered in minimum
#   return np.minimum(np.std(X, axis=0, ddof=1), IQR)
# C:\Users\Rebecca\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# C:\Users\Rebecca\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# ...

# %%
# KDE plots of the tip distribution separated by day and sex
g = sns.FacetGrid(df, col="day", hue="sex") 
g.map(sns.distplot, "tip")

# %%
# kernel density estimation in 2 dimensions, we can do this with seaborn also. KDE for total bill vs tip plotted on 2 dimension plot. Also overlayed this plot with the scatter plot so the outliners are visible. 
sns.kdeplot(tips['total_bill'], tips['tip'], cmap='magma_r')
plt.scatter(tips['total_bill'], tips['tip'], marker='v', color='r', alpha=0.9)
plt.xlabel('total bill')
plt.ylabel('tip')
plt.title('KDE plot of total bill vs tips')
plt.show()

# %%
g = sns.jointplot(x="total_bill", y="tip", data=df, kind="kde", color="m")
g.plot_joint(plt.scatter, c="w", s=10, linewidth=1, marker="v")
g.ax_joint.collections[0].set_alpha(0)
g.set_axis_labels("$X$", "$Y$");

# %%
f, ax = plt.subplots(figsize=(6, 6))
cmap = sns.cubehelix_palette(as_cmap=True, dark=0, light=1, reverse=True)
sns.kdeplot(df.total_bill, df.tip, cmap=cmap, n_levels=20, shade=True);

# %% [markdown]
# The above 3 plots show the exact same information but in slightly different formats. In the first one all the data points are shown using a triangle. You can see that the outline values are also plotted but are ignored in the drawing of the layers. In the one above there is no sign of them. The brighter the colour shows a greater concentration in the data points selected. So, from the above it looks that there is a greater incidence of total bill totals of approximately 13 dollars with the corresponding amount of 2 dollars. There are some instances of the total bill coming to 37 dollars (again this is approx. from my reading of the plot) and the tip around 5 dollars. These plots quickly draw the eye to were the greatest convergence of where the data is.

# %%
# Only works on integers so cannot incorporate strings therefore its value is limited 
# The darker the colour the higher the concentration
sns.jointplot("total_bill", "tip",  data=df, kind='kde')

# %% [markdown]
# Violin graphs are similar to the box plot but have advantages.  Below is a straight forward violin plot.

# %%
plt.figure(figsize=(10,6))
sns.violinplot(x='sex', y='tip', data=tips)
plt.title('Violin plots of tip size by sex')
plt.xlabel('sex')
plt.ylabel('tip')
plt.show()

# %% [markdown]
# Interpreting the violin shape is very similar to how a density plot is read. The thicker part means values in that section have a higher frequency than the thinner part. The above shows that while broadly similar, the males reach above 10 dollars as a maximum tip while the females end before 8 dollars.

# %%
plt.figure(figsize=(10,6))
sns.violinplot(x='day', y='total_bill', hue="smoker", data=tips, split=True)
plt.title('Violin plots of total bill by sex')
plt.xlabel('day')
plt.ylabel('total bill')
plt.show()

# %% [markdown]
# The above is a split violin to compare the difference between smokers and non-smokers each day on the total amount spent on the bill. On Thursday the smokers peak is protruding more than non-smokers showing that more smokers spent 18 dollars while the peak protrudes more at 15 for non-smokers, meaning more non-smokers spent 15 dollars on the bill. Friday smokers peaked at 14 dollars but there were still some smokers spending up to 50 dollars. Non-smokers bills started at 8 dollars; their peak was just above 20 dollars but they didn’t spend more than 30 dollars altogether. Saturday non-smokers peaked more than smokers at 19 dollars while smokers were somewhat level from 12 to 28 dollars. Both have almost the same maximum spent at 60 dollars. Sunday non-smokers peak occurs at just under 20 dollars and declines rapidly to about 50 dollars. Smokers peak at 19 dollars but they hold more paying up to 29 dollars and then drops.

# %%
plt.figure(figsize=(10,6))
sns.violinplot(x='day', y='size', data=tips, inner="quartile", hue="sex", split=True)
plt.title('size each day')
plt.xlabel('day')
plt.ylabel('size')
plt.show()

# %% [markdown]
# Above shows the total bill each day but this time the quartiles are drawn as horizontal lines, rather than a mini-box. Thursday had slightly more groups of 2 males than females, Friday had mostly females in groups of 2 or more. In fact, there were no female groups of less than 2 so no female dined alone. Looking at the original tips table, it gives the sex of the person paying the bill and the number of people in the group. It doesn’t go into greater detail to state the sex of each member of the party. Saturday there were more in the female groups of 2. Sunday there were more groups of 2 men. While females had a steadier curve that peaked at 2 in the group and slowly declined while tapering off at 4 in the party. Again, I don’t think this is a good representation of the information as it doesn’t go into detail on the individual members of the group and their sex.

# %% [markdown]
# Pointplots quickly show the difference in slopes when compared to the heights of barplots or countplots.

# %%
# Only select those who ate on Friday

import seaborn as sb
df = variable.loc [variable.loc [:, "day"] == "Fri"]
sb.pointplot(x = "tip", y = "total_bill", hue = "sex", data = df)
plt.show()

# %% [markdown]
# The information isn’t displayed well and difficult to understand.

# %%
# Again only those who ate on Friday.  The graph still isn’t very good so I will widen the search criteria to include all days and see if it looks any better
df = variable.loc [variable.loc [:, "day"] == "Fri"]
sb.pointplot(x = "time", y = "total_bill", hue = "smoker", data = df)
plt.show()

# %% [markdown]
# The information still isn’t easy to read.

# %%
# Same parameters selected but this time all the days are selected.  The graph looks much better.
df = tips
sb.pointplot(x = "time", y = "total_bill", hue = "smoker", data = df)
plt.show()

# %%
# Same information as above but using a different line style
df = tips
sb.pointplot(x = "time", y = "total_bill", hue = "smoker", data = df, markers=["o", "x"], linestyles=["-", "--"])
plt.show()

# %% [markdown]
# Smokers had slightly higher bills at lunch times than non-smokers.  At dinner time the smokers again had larger bills than non-smokers but this time the difference was larger with smokers at just under 22 dollars and non-smokers at just above 20 dollars.

# %%
# Drawing horizontal points between the days and the total bills and the sex of the customer.
sb.pointplot(x="day", y="total_bill", hue="sex", data=tips, color="#bb5f5f")

# %% [markdown]
# The above shows that female bills were consistently smaller than the males with a noticeable dip on Friday.  Males total bill amounts climbed steadily from Thursday to Sunday.

# %%
# Same information as above but using a different line style
df = tips
sb.pointplot(x = "time", y = "total_bill", hue = "smoker", data = df, markers=["o", "x"], linestyles=["-", "--"])
plt.show()

# %%
# Scatter plot showing which sex paid the most daily.
sns.catplot(x="day", y="total_bill", hue='sex', col="time", data=tips, kind="point", dodge=True, height=4, aspect=.7);

# %% [markdown]
# As already noted, there was only lunch time data recorded for Thursday and Friday.  Males spent more on Thursday but females spent more on Friday.  Dinner time had no data for males on Thursday but for the remaining days males spent more than females with a large discrepancy on Friday that shortened Saturday and Sunday. Males total bills dropped Friday to Saturday but rose slightly on Sunday.  Females dropped Thursday to Friday, climbed back on Saturday and remained mostly the same on Sunday.

# %% [markdown]
# ## Summary for this section

# %% [markdown]
# From a server point of view; lunch time percentage tips are similary between males and females but dinner time the males are far higher.  Smaller non smoking tables tip better.
#
# But if management were using this to try and predict required staffing, stock levels and seating arrangements; Saturday made the most money (1778.40) and had the most people (219), closely followed by Sunday. (1672.16, 216).  Baring in mind that there was no lunch service on these days. Thursday was almost all lunch trade.  Non smokers higher bills and tips.  Saturday had the most amount of 2 people tables closely followed by Thursday, then Sunday and finally Friday. 2 people tables were the most popular. 3 and 4 people tables were the next popular. There were very few 1, 5 or 6 people tables.

# %% [markdown]
# Machine Learning  - currently beyond my ability but I thought it would be interesting to include this.  According to https://devarea.com/python-machine-learning-example-linear-regression/#.XdMC4uj7SUk before the model can be built the data has to be cleaned and all text values converted into numbers.  There are a few different ways to do it including:
# Using update statements
# Using replace method
# Iterate over the rows
# Use dummy variables

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
# total_bill    244 non-null float64
# tip           244 non-null float64
# sex           244 non-null category
# smoker        244 non-null category
# day           244 non-null category
# time          244 non-null category
# size          244 non-null int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.2 KB

# %%
# Reload what the program calls as tips as it was throwing up an error without it
df=sb.load_dataset('tips')

# %%
# A repeat of earlier, what is the busiest day to work.
df.groupby('day').count()
# Out:
#       total_bill  tip  sex  smoker  time  size
# day
# Thur          62   62   62      62    62    62
# Fri           19   19   19      19    19    19
# Sat           87   87   87      87    87    87
# Sun           76   76   76      76    76    76

# %%
# Convert the sex and smoker columns to values
df.replace({ 'sex': {'Male':0 , 'Female':1} , 'smoker' : {'No': 0 , 'Yes': 1}} ,inplace=True)
df.head()
# Out:
#    total_bill   tip  sex  smoker  day    time  size
# 0       16.99  1.01    1       0  Sun  Dinner     2
# 1       10.34  1.66    0       0  Sun  Dinner     3
# 2       21.01  3.50    0       0  Sun  Dinner     3
# 3       23.68  3.31    0       0  Sun  Dinner     2
# 4       24.59  3.61    1       0  Sun  Dinner     4

# %%
# using dummy variables. The values in day column are:  Thu, Fri, Sat, Sun we can convert it to 1,2,3,4 but to get a good model, it is better to use boolean variables. We can achieve it by converting the column into 4 columns – one for each day with 0 or 1 as values. In pandas library it can be done using get_dummies:
days=pd.get_dummies(df['day'])
days.sample(5)
# Out:
#      Thur  Fri  Sat  Sun
# 208     0    0    1    0
# 67      0    0    1    0
# 74      0    0    1    0
# 83      1    0    0    0
# 120     1    0    0    0

# %%
# drop one of the columns without loosing data – for example if we drop column ‘Thur’ we know that index 135 is Thur because all other days are 0. It is also supported by the same function:
days=pd.get_dummies(df['day'],drop_first=True)
days.sample(6)
# Out:
#      Fri  Sat  Sun
# 229    0    1    0
# 108    0    1    0
# 214    0    1    0
# 85     0    0    0
# 28     0    1    0
# 146    0    0    0

# %%
# same with time column and concat all data frames, Also we don’t need the day and size columns anymore so we drop them
days=pd.get_dummies(df['day'],drop_first=True)
df = pd.concat([df,days],axis=1)
times=pd.get_dummies(df['time'],drop_first=True)
df = pd.concat([df,times],axis=1)
df.drop(['day','time'],inplace=True,axis=1)
df.head()
# Out:
#    total_bill   tip  sex  smoker  size  Fri  Sat  Sun  Dinner
# 0       16.99  1.01    1       0     2    0    0    1       1
# 1       10.34  1.66    0       0     3    0    0    1       1
# 2       21.01  3.50    0       0     3    0    0    1       1
# 3       23.68  3.31    0       0     2    0    0    1       1
# 4       24.59  3.61    1       0     4    0    0    1       1

# %%
# ready to build the linear regression model:

# We create a list of features as X and predicted as Y
X = df[['sex','smoker','size','Fri','Sat','Sun','Dinner']]
Y = df[['tip']]

# %%
# split the data into test and train so we can test our model before we use it – we decide to split 70% – 30%:
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
X_train, X_test , y_train , y_test = train_test_split(X,Y,test_size=0.25,random_state=26)

# %%
#train the model with X_train and y_train:
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
#predict the X_test values:
predictions=model.predict(X_test)

# %%
# We can now look at the predictions and compare it with y_test

#We can draw a graph to see the difference distribution:
sb.distplot(y_test-predictions)
# Out:
# C:\Users\Rebecca\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# It can be seen from the graph that most of the times the predictions were correct (difference = 0). We can continue working on the model , adding data and play with the parameters

# %%
# predict new value for example :

# We have a 3 size table smoker male on friday lunch:
myvals = np.array([0,1,3,1,0,0,0]).reshape(1,-1)
model.predict(myvals)
# We expect a tip of 3.12
# Out:
# array([[3.12444493]])

# %%
# We have a 4 size table smoker female on friday lunch
myvals = np.array([1,1,4,1,0,0,0]).reshape(1,-1)
model.predict(myvals)
# Out:
# array([[3.82319315]])

# %% [markdown]
# ## Conclusion

# %% [markdown]
# From the plots, graphs and calculations, the tips do seem to mostly follow the 15 to 20% convention. There is always the risk that the data has been incorrectly entered either by accident or deliberately. There are what appear to be some omissions, namely that there is no dinner information for males on Thursdays. If the information was conducted over a long period then this is very unusual. There is no information for lunch on Saturday or Sundays. This could be due to a number of reasons. The employee may have had that shift off, the restaurant may have been closed and only open for dinner.  There are also a number of other possibilities which may have influenced the data e.g. special celebrations and occasions such as a wedding or party.  Any of these would have higher bills and resulted in higher tips.  And there are external factors which could have an effect on the results i.e. poor customer service or a bias torwards the sex of the customer, smoking status or party size.  I also find it curious that the type of restaurant is not known.  Generally, fast food restaurants do not have tipping as there is no table service (server brings the food to a table) so it would be safe to assume this is not that kind of establishment.
#
# Without being able to verify the veracity of the information first-hand it is difficult to account for these omissions. And as this dataset was collected almost 30 years ago it is hard to validate it. There are more datasets available that are more recent and with more information which could be also looked at a future date and compare this with.
#
# This dataset was very different from the Iris data set which I looked at last year. The sepal and petal sizes do not change significantly over 30 years but the eating patterns of people do. Population size, spending patterns, saturation and competition of the restaurant market, dietary change, and online deliveries have made the information from 30 years ago a lot less relevant and difficult to translate into usable information today for current markets and trends but as a machine learning model it is still usable.
#
# There is a lot of information and plots in this assignment. I did this for a few reasons. Not all plot types are suited to all types of information and sometimes a limited number of variables are needed to highlight a relevant point. This was a learning experience for me in that I had to try many ones and see what worked to display the information and what did not. I found it hugely enjoyable to see what I could produce and could easily have kept going trying more but I did not want to over saturate the assignment and produce a long boring (not to me though) description. I commented on the outputs of most of the scripts, excluding duplicates. Some of the scripts may have been surplus to the brief of the assignment but I wanted to re acquaint myself with some of the functions and try out new ones. These will be used in future to remind myself and build on.
